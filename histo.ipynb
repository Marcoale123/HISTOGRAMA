# %%
import pandas as pd
import numpy as np
import cv2 
import matplotlib.pyplot as plt

# %%
img = "./imagenes/NORMAL/NORMAL2-IM-1431-0001.jpeg"

# %%
img = cv2.imread(img_path, cv2.IMREAD_GRAYSCALE)

# %%
def expand_histogram(image):
    min_val = np.min(image)
    max_val = np.max(image)
    stretched = ((image - min_val) / (max_val - min_val) * 255).astype(np.uint8)
    return stretched

# %%
def equalize_histogram(image):
    return cv2.equalizeHist(image)

# %%
expanded = expand_histogram(img)
equalized = equalize_histogram(img)

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.imshow(img, cmap='gray')
plt.title("Original")
plt.axis("off")

plt.subplot(1, 3, 2)
plt.imshow(expanded, cmap='gray')
plt.title("Expansión de Histograma")
plt.axis("off")

plt.subplot(1, 3, 3)
plt.imshow(equalized, cmap='gray')
plt.title("Ecualización de Histograma")
plt.axis("off")

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(2, 3, figsize=(15, 8))

# Imágenes
axs[0, 0].imshow(img, cmap='gray')
axs[0, 0].set_title("Original")
axs[0, 0].axis("off")

axs[0, 1].imshow(expanded, cmap='gray')
axs[0, 1].set_title("Expandida")
axs[0, 1].axis("off")

axs[0, 2].imshow(equalized, cmap='gray')
axs[0, 2].set_title("Ecualizada")
axs[0, 2].axis("off")

# Histogramas
axs[1, 0].hist(img.ravel(), 256, [0, 256])
axs[1, 0].set_title("Histograma Original")

axs[1, 1].hist(expanded.ravel(), 256, [0, 256])
axs[1, 1].set_title("Histograma Expandido")

axs[1, 2].hist(equalized.ravel(), 256, [0, 256])
axs[1, 2].set_title("Histograma Ecualizado")

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_16604/2014660739.py:17: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   axs[1, 0].hist(img.ravel(), 256, [0, 256])
# /tmp/ipykernel_16604/2014660739.py:20: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   axs[1, 1].hist(expanded.ravel(), 256, [0, 256])
# /tmp/ipykernel_16604/2014660739.py:23: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.10; the parameter will become keyword-only in 3.12.
#   axs[1, 2].hist(equalized.ravel(), 256, [0, 256])
